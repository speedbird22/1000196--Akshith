# %%
# %pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.8.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (0.6.10)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.155.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.25.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.10.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.10->google-generativeai) (1.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (2.27.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.12.14)

# %%
import google.generativeai as genai
GOOGLE_API_KEY = "AIzaSyDYzoCt1v6ixZ0N_i3VGiLAL1g0n3DPKJM"
genai.configure(api_key=GOOGLE_API_KEY)
for m in genai.list_models():
	if 'generateContent' in m.supported_generation_methods:
  print(m.name)
# Out:
#   File "<tokenize>", line 6
#     print(m.name)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import google.generativeai as genai
GOOGLE_API_KEY = "AIzaSyDYzoCt1v6ixZ0N_i3VGiLAL1g0n3DPKJM"
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-1.5-pro-latest')
response = model.generate_content("Please provide a list of the most influential people in the world.")
print(response.text)
# Out:
# It's impossible to create a definitive, objective list of the "most influential" people in the world. Influence is subjective, multifaceted, and constantly shifting.  Any list will be inherently biased and reflect the perspective of the person creating it.
#
# However, I can offer a list of individuals who are widely considered to be highly influential in 2024, categorized by their sphere of influence:
#
# **Politics & Governance:**
#
# * **Xi Jinping:**  President of China, leading a global superpower.
# * **Joe Biden:** President of the United States, leading another global superpower.
# * **Narendra Modi:** Prime Minister of India, leading the world's most populous democracy.
# * **Ursula von der Leyen:** President of the European Commission, influencing policy across Europe.
# * **António Guterres:** Secretary-General of the United Nations, addressing global issues.
# * **Leaders of other major nations:**  Including those of Russia, France, Germany, the UK, Japan, Brazil, etc.
#
# **Business & Technology:**
#
# * **Elon Musk:** CEO of Tesla, SpaceX, and X (formerly Twitter), driving innovation in electric vehicles, space exploration, and social media.
# * **Tim Cook:** CEO of Apple, leading a highly influential tech company.
# * **Sundar Pichai:** CEO of Alphabet (Google), overseeing a dominant force in search, advertising, and AI.
# * **Satya Nadella:** CEO of Microsoft, leading a resurgent tech giant in cloud computing and AI.
# * **Mark Zuckerberg:** CEO of Meta Platforms (Facebook, Instagram, WhatsApp), shaping social media and the metaverse.
# * **Jeff Bezos:** Founder of Amazon, a major player in e-commerce, cloud computing, and space exploration.
#
# **Finance & Economics:**
#
# * **Christine Lagarde:** President of the European Central Bank, influencing monetary policy in the Eurozone.
# * **Jerome Powell:** Chair of the Federal Reserve, influencing US monetary policy and the global economy.
# * **Heads of other major central banks:**  Including those of China, Japan, and the UK.
# * **Influential investors and economists:**  Such as Warren Buffett, Bill Gates, and prominent academics.
#
# **Science & Medicine:**
#
# * **Leading scientists and researchers:** Particularly those involved in crucial fields like climate change, artificial intelligence, and medicine (e.g., developers of mRNA vaccines).
# * **Directors of major health organizations:**  Such as the WHO and the CDC.
#
# **Arts & Culture:**
#
# * **Highly acclaimed artists, musicians, writers, and filmmakers:**  Whose work reaches and influences large audiences.
# * **Social media influencers:** Who shape opinions and trends, particularly among younger generations.
#
# **Activism & Advocacy:**
#
# * **Prominent activists and advocates:**  Working on issues like climate change, human rights, and social justice.  (e.g., Greta Thunberg).
# * **Religious leaders:**  Whose teachings and guidance influence millions of followers.
#
# **This list is not exhaustive and is constantly evolving.**  Influence can be wielded in many ways, and some individuals may have a profound impact despite not holding a high-profile position.  It's important to consider this list as a starting point for further exploration and discussion.

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name) # Corrected indentation: 4 spaces
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental

# %%
import google.generativeai as genai

# Set API key for the Gemini 1.5 Pro Model
GOOGLE_API_KEY = "AIzaSyDYzoCt1v6ixZ0N_i3VGiLAL1g0n3DPKJM"
genai.configure(api_key=GOOGLE_API_KEY)

# Define function to generate fashion recommendations
def generate_fashion_recommendation(body_type, style_preference, occasion):
    prompt = (f"Suggest an outfit for a user with a {body_type} body type who prefers "
              f"{style_preference} style for a {occasion}. Provide outfit details including "
              "clothing items, colors, and accessories suitable for this context.")

    # Generate content using Gemini API
    model = genai.GenerativeModel('gemini-1.5-pro-latest')
    response = model.generate_content(prompt)

    # Print the response
    print("Fashion Recommendation:")
    print(response.text)

# Example: Call function with user inputs
body_type = "athletic"
style_preference = "modern casual"
occasion = "weekend outing"
generate_fashion_recommendation(body_type, style_preference, occasion)
# Out:
# Fashion Recommendation:
# **Outfit:**
#
# * **Top:**  Fitted, dark grey Henley shirt. This highlights the athletic build without being too tight, and the Henley style adds a touch of casual sophistication.
# * **Bottoms:** Slim-fit, light wash denim jeans or dark olive chinos.  Choose the jeans for a more relaxed feel, the chinos for a slightly elevated casual look. Ensure they fit well without being constricting.
# * **Outerwear (Optional, depending on weather):**  A lightweight bomber jacket in navy or army green.  Bomber jackets complement athletic builds and add a cool, contemporary edge. Alternatively, a light grey or charcoal cardigan can provide a softer, more relaxed look.
# * **Shoes:** Crisp white leather sneakers or stylish suede desert boots in a light brown or beige. White sneakers maintain the casual vibe while desert boots bring a touch of rugged elegance.
#
# **Colors:**
#
# The color palette is neutral and versatile, allowing for easy mixing and matching with other pieces.  The contrast between the darker top and lighter bottoms is visually appealing and flattering. The pop of white from the sneakers adds freshness.
#
# **Accessories:**
#
# * **Watch:** A minimalist watch with a leather or metal band. Opt for a clean design in silver, black, or brown.
# * **Sunglasses:**  Classic aviator or wayfarer style sunglasses.
# * **Bracelet (Optional):** A simple leather or beaded bracelet.  Avoid anything too flashy or bulky.
#
#
# **Example Outfit Combinations:**
#
# * Dark grey Henley, light wash jeans, white sneakers, navy bomber jacket, aviator sunglasses, minimalist silver watch.
# * Dark grey Henley, dark olive chinos, beige desert boots, charcoal cardigan, wayfarer sunglasses, leather bracelet, minimalist brown watch.
#
#
# **Key Considerations for Athletic Builds:**
#
# * **Fit:**  Choose clothes that fit well but aren't too tight. Show off your physique without looking like you're trying too hard.
# * **Fabric:** Opt for breathable and comfortable fabrics like cotton, linen, or performance blends.
# * **Layering:** Layering pieces like a Henley and a bomber jacket can add depth and visual interest to the outfit.
#
#
#
# This outfit balances comfort and style, making it perfect for a casual weekend outing like brunch, a walk in the park, or exploring a new city.  It's versatile and can be easily dressed up or down with a simple change of shoes or outerwear.

# %%
import google.generativeai as genai

# Configure Gemini API
GOOGLE_API_KEY = "AIzaSyDYzoCt1v6ixZ0N_i3VGiLAL1g0n3DPKJM"
genai.configure(api_key=GOOGLE_API_KEY)

# Greeting the user
print("Welcome to Your Personalized Fashion Recommender!")
print("Please provide some information to get tailored outfit suggestions.\n")

# Collect user inputs
body_type = input("Enter your body type (e.g., Slim, Athletic, Pear-shaped): ").strip()
style_preference = input("What is your preferred style? (e.g., modern casual, elegant formal): ").strip()
occasion = input("What occasion is this outfit for? (e.g., business meeting, weekend outing): ").strip()

# Generate fashion recommendation
def generate_fashion_recommendation(body_type, style_preference, occasion):
    prompt = (f"Suggest an outfit for a user with a {body_type} body type who prefers "
              f"{style_preference} style for a {occasion}. Provide outfit details including "
              "clothing items, colors, and accessories suitable for this context.")

    # Generate content using Gemini API
    model = genai.GenerativeModel('gemini-1.5-pro-latest')
    response = model.generate_content(prompt)

    # Display the recommendation
    print("\nYour Fashion Recommendation:")
    print(response.text)

# Call the function with user inputs
generate_fashion_recommendation(body_type, style_preference, occasion)
# Out:
# Welcome to Your Personalized Fashion Recommender!
# Please provide some information to get tailored outfit suggestions.
#
# Enter your body type (e.g., Slim, Athletic, Pear-shaped): slim, athletic, pear shaped
# What is your preferred style? (e.g., modern casual, elegant formal): formal
# What occasion is this outfit for? (e.g., business meeting, weekend outing): holiday
#
# Your Fashion Recommendation:
# For a slim, athletic, pear-shaped body type, the goal for a formal holiday outfit is to balance the proportions and accentuate the upper body while streamlining the lower half.
#
# **Outfit Idea:**
#
# * **Top:** A jewel-toned velvet or silk top with interesting details like a ruffle neck, puffed sleeves, or embellished neckline.  Colors like emerald green, sapphire blue, ruby red, or deep purple work beautifully for the holidays and draw the eye upwards.  Alternatively, a festive patterned top with a darker background and brighter accents can also work well.  The key is to add volume and visual interest to the upper body.
#
# * **Bottom:**  Dark-colored, tailored trousers or a sleek, A-line midi skirt in a heavier fabric like wool or gabardine.  Black, navy, or deep charcoal grey are slimming and elegant. Avoid clingy fabrics or overly embellished bottoms.  If choosing a skirt, ensure it skims over the hips and doesn't cling.  A midi length is both flattering and appropriate for a formal occasion.
#
# * **Outerwear (optional):** A structured blazer or a fitted coat in a complementary color or a neutral like black or camel. A slightly longer blazer that falls below the hips can help create a balanced silhouette.
#
# **Accessories:**
#
# * **Jewelry:**  Statement earrings or a necklace to draw attention to the face and neckline.  A delicate pendant or chandelier earrings would complement the look without overwhelming the outfit.
#
# * **Shoes:** Heels or pointed-toe flats in a coordinating color. Heels can elongate the legs and add a touch of formality.  If choosing flats, ensure they have a pointed or slightly elongated toe to maintain a streamlined appearance.
#
# * **Bag:** A clutch or a small shoulder bag in a metallic or jewel tone.  A structured bag complements the formal look.
#
# * **Other:** A festive belt cinched at the natural waist can help define the waistline and create a balanced silhouette, especially if wearing a top that isn't already fitted.
#
#
# **Example Outfit Combination:**
#
# * Emerald green velvet top with subtle puff sleeves
# * Black tailored trousers
# * Black pointed-toe heels
# * Gold statement earrings
# * Black clutch with gold hardware
#
#
# **Example Outfit Combination 2:**
#
# * Burgundy and gold patterned silk top
# * Navy A-line midi skirt
# * Navy fitted blazer
# * Burgundy velvet pumps
# * Delicate gold pendant necklace
# * Small burgundy shoulder bag
#
#
# Remember to choose fabrics that drape well and feel comfortable.  The key is to create a balanced and polished look that celebrates your body shape and reflects the festive holiday spirit.

# %%
import google.generativeai as genai

# Configure Gemini API
GOOGLE_API_KEY = "AIzaSyDYzoCt1v6ixZ0N_i3VGiLAL1g0n3DPKJM"
genai.configure(api_key=GOOGLE_API_KEY)

# Greeting the user
print("Welcome to Your Personalized Fashion Recommender!")
print("Please provide some information to get tailored outfit suggestions.\n")

# Collect user inputs
body_type = input("Enter your body type (e.g., Slim, Athletic, Pear-shaped): ").strip()
style_preference = input("What is your preferred style? (e.g., modern casual, elegant formal): ").strip()
occasion = input("What occasion is this outfit for? (e.g., business meeting, weekend outing): ").strip()

# Display humorous waiting message
print("\nPlease hold on as I consult the finest fashion minds in the digital realm to craft the perfect wardrobe recommendation tailored to your impeccable taste...\n")

# Generate fashion recommendation
def generate_fashion_recommendation(body_type, style_preference, occasion):
    prompt = (f"Suggest an outfit for a user with a {body_type} body type who prefers "
              f"{style_preference} style for a {occasion}. Provide outfit details including "
              "clothing items, colors, and accessories suitable for this context.")

    # Generate content using Gemini API
    model = genai.GenerativeModel('gemini-1.5-pro-latest')
    response = model.generate_content(prompt)

    # Display the recommendation
    print("Your Fashion Recommendation:")
    print(response.text)

# Call the function with user inputs
generate_fashion_recommendation(body_type, style_preference, occasion)
# Out:
# Welcome to Your Personalized Fashion Recommender!
# Please provide some information to get tailored outfit suggestions.
#
# Enter your body type (e.g., Slim, Athletic, Pear-shaped): fat
# What is your preferred style? (e.g., modern casual, elegant formal): modern
# What occasion is this outfit for? (e.g., business meeting, weekend outing): formal
#
# Please hold on as I consult the finest fashion minds in the digital realm to craft the perfect wardrobe recommendation tailored to your impeccable taste...
#
# Your Fashion Recommendation:
# For a modern formal look that flatters a larger body type, consider a sophisticated and stylish ensemble that emphasizes comfort and confidence.
#
# **Clothing Items:**
#
# * **A-Line or Fit-and-Flare Dress:** This silhouette is universally flattering, skimming over the midsection and creating a balanced look. Avoid overly clingy or boxy shapes.  Look for a dress that hits just below the knee or midi length for a modern and elegant feel.
# * **Wrap Dress:**  A wrap dress is another excellent option as it cinches at the waist, creating a flattering shape while providing adjustability. Choose a wrap dress with a V-neckline to elongate the torso.
# * **Jumpsuit:** A well-tailored jumpsuit can be a chic and modern alternative to a dress. Look for a wide-leg jumpsuit with a defined waist. Avoid overly baggy styles.
#
# **Colors:**
#
# * **Darker Jewel Tones:** Emerald green, sapphire blue, or ruby red can be incredibly flattering and elegant.
# * **Classic Black or Navy:** These are always safe bets and create a slimming effect.
# * **Rich, Deep Colors:**  Burgundy, forest green, or deep plum are stylish and sophisticated.
# * **Avoid overly bright or neon colors:** These can draw attention to areas you may not want to emphasize.
#
# **Fabric:**
#
# * **Structured Fabrics:** Look for fabrics that hold their shape well, such as crepe, scuba, or a thicker jersey. Avoid flimsy or clingy materials.
#
# **Accessories:**
#
# * **Statement Necklace:** A bold necklace draws the eye upwards and adds a touch of glamour.
# * **Delicate Earrings:** Choose earrings that complement the necklace without overwhelming the overall look.
# * **Clutch or Small Handbag:** A sleek clutch or small handbag adds a polished touch.
# * **Heels or Dressy Flats:**  Heels can elongate the legs, but comfortable dressy flats are also a great option. Choose shoes that provide good support.
# * **Shapewear (Optional):**  If desired, shapewear can provide extra smoothing and support.
#
#
# **Example Outfit 1:**
#
# * **A-Line Midi Dress:**  Navy blue A-line dress in a structured crepe fabric.
# * **Shoes:**  Nude or silver heels.
# * **Accessories:**  Silver statement necklace, matching earrings, and a silver clutch.
#
#
# **Example Outfit 2:**
#
# * **Wrap Dress:** Emerald green wrap dress in a luxurious jersey fabric.
# * **Shoes:** Black or gold dressy flats.
# * **Accessories:** Gold pendant necklace, delicate gold earrings, and a black clutch.
#
#
# **Example Outfit 3:**
#
# * **Jumpsuit:** Black wide-leg jumpsuit with a defined waist.
# * **Shoes:**  Red heels.
# * **Accessories:**  Gold statement earrings, a red clutch, and a thin gold belt.
#
# **Most Importantly:**  Choose an outfit that makes you feel confident and comfortable. Confidence is the key to looking and feeling your best at any formal event.  Don't be afraid to experiment with different styles and find what works best for your body type and personal style.

# %%
import google.generativeai as genai

# Configure Gemini API
GOOGLE_API_KEY = "AIzaSyDYzoCt1v6ixZ0N_i3VGiLAL1g0n3DPKJM"
genai.configure(api_key=GOOGLE_API_KEY)

# Greeting the user
print("Welcome to Your Personalized Fashion Recommender!")
print("Please provide some information to get tailored outfit suggestions.\n")

# Collect user inputs
body_type = input("Enter your body type (e.g., Slim, Athletic, Pear-shaped) or leave blank to analyze from image : ").strip()
style_preference = input("What is your preferred style? (e.g., modern casual, elegant formal):").strip()
occasion = input("What occasion is this outfit for? (e.g., business meeting, weekend outing): ").strip()

# Image input placeholder
image_path = input("If you'd like me to analyze your style from an image, enter the image file path (e.g., 'example.jpg') or leave blank to skip: ").strip()

# Display humorous waiting message
print("\nPlease hold on as I consult the finest fashion minds in the digital realm to craft the perfect wardrobe recommendation tailored to your impeccable taste...\n")

# Placeholder for image analysis logic
def analyze_image(image_path):
    if image_path:
        print(f"Analyzing the image at '{image_path}' to determine body type and current fashion style...\n")
        # Placeholder for real image processing logic
        # This would be replaced by code to extract body type and fashion style
        # Assuming Gemini model API or similar service supports image uploads directly
        return "Athletic", "Modern trendy"
    return body_type  # Fallback to user-provided body type if no image

# Generate fashion recommendation
def generate_fashion_recommendation(body_type, style_preference, occasion):
    prompt = (f"Suggest an outfit for a user with a {body_type} body type who prefers "
              f"{style_preference} style for a {occasion}. Provide outfit details including "
              "clothing items, colors, and accessories suitable for this context.")

    # Generate content using Gemini API
    model = genai.GenerativeModel('gemini-1.5-pro-latest')
    response = model.generate_content(prompt)

    # Display the recommendation
    print("Your Fashion Recommendation:")
    print(response.text)

# Use the image analysis function or fallback to user input
final_body_type = analyze_image(image_path)
generate_fashion_recommendation(final_body_type, style_preference, occasion)
# Out:
# Welcome to Your Personalized Fashion Recommender!
# Please provide some information to get tailored outfit suggestions.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-97a4ff91d3f1> in <cell line: 12>()
#      10
#      11 # Collect user inputs
# ---> 12 body_type = input("Enter your body type (e.g., Slim, Athletic, Pear-shaped) or leave blank to analyze from image : ").strip()
#      13 style_preference = input("What is your preferred style? (e.g., modern casual, elegant formal):").strip()
#      14 occasion = input("What occasion is this outfit for? (e.g., business meeting, weekend outing): ").strip()
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import google.generativeai as genai

# Configure Gemini API
GOOGLE_API_KEY = "AIzaSyDYzoCt1v6ixZ0N_i3VGiLAL1g0n3DPKJM"
genai.configure(api_key=GOOGLE_API_KEY)

# Greeting the user
print("Welcome to Your Personalized Fashion Recommender!")
print("Please provide some information to get tailored outfit suggestions.\n")

# Collect user inputs
body_type = input("Enter your body type (e.g., Slim, Athletic, Pear-shaped) or leave blank to analyze from image: ").strip()
style_preference = input("What is your preferred style? (e.g., modern casual, elegant formal): ").strip()
occasion = input("What occasion is this outfit for? (e.g., business meeting, weekend outing): ").strip()
temperature = input("What is the temperature in your area? (Hot, Cold, or Room temperature): ").strip().lower()
color_preference = input("Do you have a color preference for your outfit? (e.g., neutral tones, bright colors, no preference): ").strip()
fit_preference = input("What fit do you prefer? (e.g., loose, tailored, slim fit): ").strip()
material_preference = input("Do you have a preferred material? (e.g., cotton, wool, synthetic, no preference): ").strip()
accessory_preference = input("Do you prefer minimal accessories, statement pieces, or no accessories at all?: ").strip()

# Image input placeholder
image_path = input("If you'd like me to analyze your style from an image, enter the image file path (e.g., 'example.jpg') or leave blank to skip: ").strip()

# Display humorous waiting message
print("\nPlease hold on as I consult the finest fashion minds in the digital realm to craft the perfect wardrobe recommendation tailored to your impeccable taste...\n")

# Placeholder for image analysis logic
def analyze_image(image_path):
    if image_path:
        print(f"Analyzing the image at '{image_path}' to determine body type and current fashion style...\n")
        # Placeholder for real image processing logic
        # This would be replaced by code to extract body type and fashion style
        # Assuming Gemini model API or similar service supports image uploads directly
        return "Athletic", "Modern trendy"
    return body_type  # Fallback to user-provided body type if no image

# Generate fashion recommendation
def generate_fashion_recommendation(body_type, style_preference, occasion, temperature, color_preference, fit_preference, material_preference, accessory_preference):
    # Modify the prompt based on temperature
    weather_suggestion = {
        "hot": "light, breathable fabrics like cotton or linen and minimal layering.",
        "cold": "warm, layered clothing with coats, sweaters, and scarves.",
        "room temperature": "comfortable outfits suitable for moderate weather."
    }
    weather_prompt = weather_suggestion.get(temperature, "appropriate for the given temperature.")

    prompt = (f"Suggest an outfit for a user with a {body_type} body type who prefers {style_preference} style for a {occasion}. "
              f"The outfit should be {weather_prompt} Include clothing items, colors, and accessories suitable for this context. "
              f"The user prefers {color_preference} colors, {fit_preference} fit, {material_preference} materials, and {accessory_preference}.")

    # Generate content using Gemini API
    model = genai.GenerativeModel('gemini-1.5-pro-latest')
    response = model.generate_content(prompt)

    # Display the recommendation
    print("Your Fashion Recommendation:")
    print(response.text)

# Use the image analysis function or fallback to user input
final_body_type = analyze_image(image_path)
generate_fashion_recommendation(final_body_type, style_preference, occasion, temperature, color_preference, fit_preference, material_preference, accessory_preference)
# Out:
# Welcome to Your Personalized Fashion Recommender!
# Please provide some information to get tailored outfit suggestions.
#
# Enter your body type (e.g., Slim, Athletic, Pear-shaped) or leave blank to analyze from image:
# What is your preferred style? (e.g., modern casual, elegant formal):
# What occasion is this outfit for? (e.g., business meeting, weekend outing):
# What is the temperature in your area? (Hot, Cold, or Room temperature): hot
# Do you have a color preference for your outfit? (e.g., neutral tones, bright colors, no preference): bright
# What fit do you prefer? (e.g., loose, tailored, slim fit): loose
# Do you have a preferred material? (e.g., cotton, wool, synthetic, no preference):
# Do you prefer minimal accessories, statement pieces, or no accessories at all?: none
# If you'd like me to analyze your style from an image, enter the image file path (e.g., 'example.jpg') or leave blank to skip: 1.jpeg
#
# Please hold on as I consult the finest fashion minds in the digital realm to craft the perfect wardrobe recommendation tailored to your impeccable taste...
#
# Analyzing the image at '1.jpeg' to determine body type and current fashion style...
#
# Your Fashion Recommendation:
# For an athletic, modern trendy individual heading to a summer picnic, prioritizing bright colors, loose fit, breathable fabrics, and minimal layering, here's an outfit suggestion:
#
# * **Clothing:**
#     * **Top:**  A brightly colored, loose-fit linen button-down shirt.  Think coral, turquoise, sunny yellow, or a vibrant lime green.  Leave it unbuttoned over the tank or tie it at the waist for a more fitted silhouette.
#     * **Inner Layer (Optional):** A simple white or cream cotton tank top or bralette for coverage.
#     * **Bottom:**  High-waisted, wide-leg linen pants in a neutral color like white, beige, or a light khaki. This balances the bright top and provides a breezy, comfortable feel.  Alternatively, a flowy midi skirt in a similar color palette would also work beautifully.
#
# * **Colors:**  The focus is on a vibrant top, complemented by neutral bottoms.  Consider a monochromatic approach for the pants/skirt and shoes to create a streamlined, modern look.
#
# * **Fabrics:** Linen is ideal for a summer picnic – it's breathable, lightweight, and drapes well. Cotton is another excellent option, especially for the inner layer.
#
# * **Accessories:**
#     * **Shoes:**  White canvas sneakers, espadrilles, or flat sandals.
#     * **Bag:** A woven tote bag or a crossbody bag in a natural material like straw or canvas.  Choose a color that complements the top or bottoms.
#     * **Jewelry:** Keep it minimal with delicate gold necklaces or some colorful beaded bracelets.
#     * **Sunglasses:**  Essential for a sunny picnic! Choose a style that complements your face shape.
#     * **Hat:** A wide-brimmed straw hat provides shade and adds a touch of chic.
#
# * **Example Outfit Combination:**  A turquoise linen button-down shirt, a white cotton tank top, white wide-leg linen pants, white canvas sneakers, a woven straw tote bag, delicate gold necklace, and aviator sunglasses.
#
# This combination offers comfort, style, and practicality for a summer picnic. The loose fit and breathable fabrics will keep the wearer cool, while the bright colors and modern silhouette reflect their personal style.

# %%
import google.generativeai as genai

# Configure Gemini API
GOOGLE_API_KEY = "AIzaSyDYzoCt1v6ixZ0N_i3VGiLAL1g0n3DPKJM"
genai.configure(api_key=GOOGLE_API_KEY)

# Greeting the user
print("Welcome to Your Personalized Fashion Recommender!")
print("Please provide some information to get tailored outfit suggestions.\n")

# Collect user inputs
body_type = input("Enter your body type (e.g., Slim, Athletic, Pear-shaped) or leave blank to analyze from image: ").strip()
style_preference = input("What is your preferred style? (e.g., modern casual, elegant formal): ").strip()
occasion = input("What occasion is this outfit for? (e.g., business meeting, weekend outing): ").strip()
temperature = input("What is the temperature in your area? (Hot, Cold, or Room temperature): ").strip().lower()
color_preference = input("Do you have a color preference for your outfit? (e.g., neutral tones, bright colors, no preference): ").strip()
fit_preference = input("What fit do you prefer? (e.g., loose, tailored, slim fit): ").strip()
material_preference = input("Do you have a preferred material? (e.g., cotton, wool, synthetic, no preference): ").strip()
accessory_preference = input("Do you prefer minimal accessories, statement pieces, or no accessories at all?: ").strip()

# Image input placeholder
image_path = input("If you'd like me to analyze your style from an image, enter the image file path (e.g., 'example.jpg') or leave blank to skip: ").strip()

# Display humorous waiting message
print("\nPlease hold on as I consult the finest fashion minds in the digital realm to craft the perfect wardrobe recommendation tailored to your impeccable taste...\n")

# Placeholder for image analysis logic
def analyze_image(image_path):
    if image_path:
        print(f"Analyzing the image at '{image_path}' to determine body type and current fashion style...\n")
        # Placeholder for real image processing logic
        # This would be replaced by code to extract body type and fashion style
        # Assuming Gemini model API or similar service supports image uploads directly
        return "Athletic", "Modern trendy"
    return body_type  # Fallback to user-provided body type if no image

# Generate fashion recommendation
def generate_fashion_recommendation(body_type, style_preference, occasion, temperature, color_preference, fit_preference, material_preference, accessory_preference):
    # Modify the prompt based on temperature
    weather_suggestion = {
        "hot": "light, breathable fabrics like cotton or linen and minimal layering.",
        "cold": "warm, layered clothing with coats, sweaters, and scarves.",
        "room temperature": "comfortable outfits suitable for moderate weather."
    }
    weather_prompt = weather_suggestion.get(temperature, "appropriate for the given temperature.")

    prompt = (f"Suggest an outfit for a user with a {body_type} body type who prefers {style_preference} style for a {occasion}. "
              f"The outfit should be {weather_prompt} Include clothing items, colors, and accessories suitable for this context. "
              f"The user prefers {color_preference} colors, {fit_preference} fit, {material_preference} materials, and {accessory_preference}.")

    # Generate content using Gemini API
    model = genai.GenerativeModel('gemini-1.5-pro-latest')
    response = model.generate_content(prompt)

    # Display the recommendation
    print("Your Fashion Recommendation:")
    print(response.text)

    # Follow-up questions
    adjustments = input("\nIs there anything you'd like to adjust or any specific preferences you'd like to add? (e.g., different color scheme, more casual, etc.): ").strip()
    if adjustments:
        print("\nTaking your adjustments into account...\n")
        adjusted_prompt = prompt + f" Please adjust the recommendation to incorporate the following preferences: {adjustments}."
        adjusted_response = model.generate_content(adjusted_prompt)
        print("Updated Fashion Recommendation:")
        print(adjusted_response.text)

# Use the image analysis function or fallback to user input
final_body_type = analyze_image(image_path)
generate_fashion_recommendation(final_body_type, style_preference, occasion, temperature, color_preference, fit_preference, material_preference, accessory_preference)
# Out:
# Welcome to Your Personalized Fashion Recommender!
# Please provide some information to get tailored outfit suggestions.
#
# Enter your body type (e.g., Slim, Athletic, Pear-shaped) or leave blank to analyze from image:
# What is your preferred style? (e.g., modern casual, elegant formal):
# What occasion is this outfit for? (e.g., business meeting, weekend outing):
# What is the temperature in your area? (Hot, Cold, or Room temperature): room temp
# Do you have a color preference for your outfit? (e.g., neutral tones, bright colors, no preference):
# What fit do you prefer? (e.g., loose, tailored, slim fit):
# Do you have a preferred material? (e.g., cotton, wool, synthetic, no preference):
# Do you prefer minimal accessories, statement pieces, or no accessories at all?:
# If you'd like me to analyze your style from an image, enter the image file path (e.g., 'example.jpg') or leave blank to skip: 1.jpeg
#
# Please hold on as I consult the finest fashion minds in the digital realm to craft the perfect wardrobe recommendation tailored to your impeccable taste...
#
# Analyzing the image at '1.jpeg' to determine body type and current fashion style...
#
# Your Fashion Recommendation:
# Please provide the missing context:
#
# * **Event/Activity:**  What is the user doing? (e.g., going to a concert, casual date, running errands, working from home)
# * **Temperature:** What's the temperature like? (e.g., 70°F and sunny, 30°F and snowy)
# * **Preferred Colors:** What colors does the user like? (e.g., earth tones, pastels, bright colors)
# * **Preferred Fit:** What kind of fit do they prefer? (e.g., slim fit, relaxed fit, oversized)
# * **Preferred Materials:** What materials do they like? (e.g., cotton, linen, silk, denim)
# * **Additional Preferences:** Any other preferences? (e.g., minimalist, bohemian, edgy)
#
# Once I have this information, I can generate a specific and helpful outfit suggestion.
#
#
# Is there anything you'd like to adjust or any specific preferences you'd like to add? (e.g., different color scheme, more casual, etc.): noting
#
# Taking your adjustments into account...
#
# Updated Fashion Recommendation:
# Since you haven't provided specific preferences for colors, fit, materials, and the event/activity, I'll create a versatile, modern trendy outfit for an athletic build that can be adapted.  This outfit assumes a moderate temperature (around 60-70°F or 15-21°C).  You can easily adjust layers depending on the actual temperature.
#
# **Outfit:**
#
# * **Top:**  Fitted, ribbed knit sleeveless turtleneck top.  This shows off the athletic build while providing a bit of warmth.  Consider colors like charcoal gray, black, olive green, or a rich navy.
# * **Overlayer:**  Cropped bomber jacket or a slightly oversized denim jacket.  The cropped length complements the fitted top and highlights the waist. Choose black, a light wash denim, or a muted army green for the jacket.
# * **Bottom:**  High-waisted, straight-leg jeans or tailored joggers.  The high waist accentuates the athletic figure.  Opt for dark wash denim for the jeans or black/gray for the joggers.
# * **Shoes:**  Chunky white sneakers or fashionable hiking boots. These provide both comfort and style and fit the modern trendy aesthetic.
#
# **Accessories:**
#
# * **Small Crossbody Bag or Belt Bag:** Practical and stylish, in a color that complements the outfit (black, brown, or a pop of color if desired).
# * **Delicate Gold Necklace:** Adds a touch of elegance without being overpowering.
# * **Hoop Earrings or Stud Earrings:** Simple and modern.
#
# **Adapting the Outfit:**
#
# * **Colder Weather:**  Add a warm layer like a knit beanie, scarf, and gloves.  Consider a longer coat like a puffer or parka instead of the bomber/denim jacket.
# * **Warmer Weather:** Ditch the overlayer and opt for the sleeveless top alone. Switch to sandals or canvas sneakers.
# * **Formal Event:** Swap the jeans/joggers for tailored trousers or a sleek midi skirt.  Elevate the shoes with heels or pointed-toe flats.  Consider a more statement jewelry piece.
# * **Casual Event:** This outfit works well as is, or you can dress it down further with a baseball cap and simpler sneakers.
#
# **Material Suggestions:**
#
# * **Top:** Cotton, modal, or a blend for comfort and breathability.
# * **Jacket:** Denim, nylon, or a cotton blend.
# * **Bottom:** Denim, cotton twill, or a comfortable performance fabric for joggers.
#
# **Fit Adjustments:**
#
# Remember to choose a fit that feels comfortable and confident.  The suggested fit is generally fitted but not skin-tight.  You can adjust based on your personal preference.
#
# By using this template and considering the specific context of the event and your personal preferences for color, materials, and fit, you can create a perfect modern trendy outfit for your athletic build.
